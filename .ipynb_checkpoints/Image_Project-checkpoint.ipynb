# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# %load_ext autoreload
#using autoreload 1 to reload all modules imported by %aimport everytime before executing the python code typed .
# %autoreload 1

# %aimport pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = cv2.imread("./test_images/straight_lines1.jpg")

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

sobel_output_x = pipeline.abs_sobel_thresh(gray,"x",(10,200))

sobel_output_y = pipeline.abs_sobel_thresh(gray,"y",(10,200))

f, (ax1,ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1 = ax1.imshow(sobel_output_x,cmap="gray")
ax2 = ax2.imshow(sobel_output_y,cmap="gray")

# %%
sobel_output_dir = pipeline.dir_threshold(gray,3 ,(np.pi/6, np.pi/2))

f, (ax1) = plt.subplots(1, 1, figsize=(20,10))
ax1 = ax1.imshow(sobel_output_dir,cmap="gray")

# %%
RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

mask_output = pipeline.thresholding(RGB)

f, (ax1) = plt.subplots(1, 1, figsize=(20,10))
ax1 = ax1.imshow(mask_output,cmap="gray")

# %%
pw_output1 = pipeline.perspective_warp(mask_output)

pw_output2 = pipeline.inv_perspective_warp(pw_output1)

f, (ax1,ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1 = ax1.imshow(pw_output1,cmap="gray")
ax2 = ax2.imshow(pw_output2,cmap="gray")

# %%
hist = pipeline.get_hist(pw_output1)

x = np.array(range(0, 1280))

plt.plot(x, hist)

ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %%
sw_output, curves, lanes, ploty = pipeline.sliding_window(pw_output1, draw_windows=True)

f, (ax1) = plt.subplots(1,1, figsize=(20,10))
ax1 = ax1.imshow(sw_output)

# %%
curverad = pipeline.get_curve(RGB, curves[0], curves[1])
lane_curve = np.mean([curverad[0], curverad[1]])
cur_output = pipeline.draw_lanes(RGB, curves[0], curves[1])

f, (ax1) = plt.subplots(1,1, figsize=(20,10))
ax1 = ax1.imshow(cur_output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Amr\OneDrive\Documents\GitHub\Lane-Detection\Image_Project.ipynb Cell 15' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000015?line=0'>1</a> curverad =get_curve(RGB, curves[0], curves[1])
#       <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000015?line=1'>2</a> lane_curve = np.mean([curverad[0], curverad[1]])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000015?line=2'>3</a> cur_output = draw_lanes(RGB, curves[0], curves[1])
#       <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000015?line=4'>5</a> f, (ax1) = plt.subplots(1,1, figsize=(20,10))
#       <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000015?line=5'>6</a> ax1 = ax1.imshow(cur_output)
#
# c:\Users\Amr\OneDrive\Documents\GitHub\Lane-Detection\Image_Project.ipynb Cell 14' in draw_lanes(img, left_fit, right_fit)
#      <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000014?line=47'>48</a> points = np.hstack((left, right))
#      <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000014?line=49'>50</a> cv2.fillPoly(color_img, np.int_(points), (0,200,255))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000014?line=51'>52</a> cv2.polylines(lane, int(left), False, color=(0,0,255), thickness=20)
#      <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000014?line=52'>53</a> cv2.polylines(lane, int(right), False, color=(255,0,0), thickness=20)
#      <a href='vscode-notebook-cell:/c%3A/Users/Amr/OneDrive/Documents/GitHub/Lane-Detection/Image_Project.ipynb#ch0000014?line=54'>55</a> inv_perspective = inv_perspective_warp(lane)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
debugging=0
def full_pipeline(img):
    th_img = thresholding(img)

    pew_img = perspective_warp(th_img)

    sw_img, curves, lanes, ploty = sliding_window(pew_img, draw_windows=True)

    curverad = get_curve(img, curves[0], curves[1])

    lane_curve = np.mean([curverad[0], curverad[1]])

    img = draw_lanes(img, curves[0], curves[1])
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    fontColor = (0, 0, 0)
    fontSize=0.5
    cv2.putText(img, 'Lane Curvature: {:.0f} m'.format(lane_curve), (570, 620), font, fontSize, fontColor, 2)
    cv2.putText(img, 'Vehicle offset: {:.4f} m'.format(curverad[2]), (570, 650), font, fontSize, fontColor, 2)
    
    if(debugging==0):
        final_img = img
    else:
        th_img_rgb = np.dstack((th_img,th_img,th_img))*255    
        pew_img_rgb = np.dstack((pew_img,pew_img,pew_img))*255
        
        img_row1 = np.concatenate((th_img_rgb, pew_img_rgb),axis = 0)
        img_row2 = np.concatenate((sw_img, img),axis = 0)

        final_img = np.concatenate((img_row1, img_row2),axis = 1)
        final_img = cv2.resize(final_img,(img.shape[1],img.shape[0]))

    return final_img

# %%
img = cv2.imread("./test_images/straight_lines1.jpg")

RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

output = full_pipeline(RGB)

f, (ax1) = plt.subplots(1,1, figsize=(20,10))
ax1 = ax1.imshow(output)
